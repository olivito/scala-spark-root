# %% [markdown]
# # Setup
# ```
# source /cvmfs/sft.cern.ch/lcg/views/LCG_88/x86_64-slc6-gcc49-opt/setup.sh
# source /cvmfs/sft.cern.ch/lcg/etc/hadoop-confext/hadoop-setconf.sh analytix
# export KRB5CCNAME=FILE:/tmp/${USER}_krb
# kinit -c /tmp/${USER}_krb
# export PYSPARK_DRIVER_PYTHON=jupyter-notebook
# export PYSPARK_DRIVER_PYTHON_OPTS="--ip=`hostname` --browser='/dev/null' --port=8889"
# pyspark --master yarn --packages org.diana-hep:spark-root_2.11:0.1.16 --files $KRB5CCNAME#krbcache --conf spark.executorEnv.KRB5CCNAME='FILE:$PWD/krbcache' --conf spark.driver.extraClassPath="/usr/lib/hadoop/EOSfs.jar"
# ```

# %%
from math import *
#import numpy as np
#from pyspark.sql import Row

# %%
filename = "root://eospublic.cern.ch//eos/opendata/cms/MonteCarlo2012/Summer12_DR53X/ZZTo4mu_8TeV-powheg-pythia6/AODSIM/PU_RD1_START53_V7N-v1/20000/"

# %%
ds = sqlContext.read.format("org.dianahep.sparkroot.experimental").option("tree","Events").load(filename)

# %%
ds.count()
# Out:
# 1499064

# %%
ds.printSchema()
# Out:
# root
#  |-- EventAuxiliary: struct (nullable = true)
#  |    |-- processHistoryID_: struct (nullable = true)
#  |    |    |-- hash_: string (nullable = true)
#  |    |-- id_: struct (nullable = true)
#  |    |    |-- run_: integer (nullable = true)
#  |    |    |-- luminosityBlock_: integer (nullable = true)
#  |    |    |-- event_: integer (nullable = true)
#  |    |-- processGUID_: string (nullable = true)
#  |    |-- time_: struct (nullable = true)
#  |    |    |-- timeLow_: integer (nullable = true)
#  |    |    |-- timeHigh_: integer (nullable = true)
#  |    |-- luminosityBlock_: integer (nullable = true)
#  |    |-- isRealData_: boolean (nullable = true)
#  |    |-- experimentType_: integer (nullable = true)
#  |    |-- bunchCrossing_: integer (nullable = true)
#  |    |-- orbitNumber_: integer (nullable = true)
#  |    |-- storeNumber_: integer (nullable = true)
#  |-- EventProductProvenance: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- branchID_: integer (nullable = true)
#  |    |    |-- parentageIDIndex_: integer (nullable = true)
#  |-- EventSelections: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- hash_: string (nullable = true)
#  |-- BranchListIndexes: array (nullable = true)
#  |    |-- element: short (containsNull = true)
#  |-- LHEEventProduct_source__LHE_: struct (nullable = true)
#  |    |-- present: boolean (nullable = true)
#  |    |-- LHEEventProduct_source__LHE_obj: struct (nullable = true)
#  |    |    |-- hepeup_: struct (nullable = true)
#  |    |    |    |-- NUP: integer (nullable = true)
#  |    |    |    |-- IDPRUP: integer (nullable = true)
#  |    |    |    |-- XWGTUP: double (nullable = true)
#  |    |    |    |-- XPDWUP: struct (nullable = true)
#  |    |    |    |    |-- first: double (nullable = true)
#  |    |    |    |    |-- second: double (nullable = true)
#  |    |    |    |-- SCALUP: double (nullable = true)
#  |    |    |    |-- AQEDUP: double (nullable = true)
#  |    |    |    |-- AQCDUP: double (nullable = true)
#  |    |    |    |-- IDUP: array (nullable = true)
#  |    |    |    |    |-- element: integer (containsNull = true)
#  |    |    |    |-- ISTUP: array (nullable = true)
#  |    |    |    |    |-- element: integer (containsNull = true)
#  |    |    |    |-- MOTHUP: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- first: integer (nullable = true)
#  |    |    |    |    |    |-- second: integer (nullable = true)
#  |    |    |    |-- ICOLUP: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- first: integer (nullable = true)
#  |    |    |    |    |    |-- second: integer (nullable = true)
#  |    |    |    |-- PUP: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- x: array (nullable = true)
#  |    |    |    |    |    |    |-- element: double (containsNull = true)
#  |    |    |    |-- VTIMUP: array (nullable = true)
#  |    |    |    |    |-- element: double (containsNull = true)
#  |    |    |    |-- SPINUP: array (nullable = true)
#  |    |    |    |    |-- element: double (containsNull = true)
#  |    |    |-- comments_: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- pdf_: struct (nullable = true)
#  |    |    |    |-- _M_ptr: struct (nullable = true)
#  |    |    |    |    |-- id: struct (nullable = true)
#  |    |    |    |    |    |-- first: integer (nullable = true)
#  |    |    |    |    |    |-- second: integer (nullable = true)
#  |    |    |    |    |-- x: struct (nullable = true)
#  |    |    |    |    |    |-- first: double (nullable = true)
#  |    |    |    |    |    |-- second: double (nullable = true)
#  |    |    |    |    |-- xPDF: struct (nullable = true)
#  |    |    |    |    |    |-- first: double (nullable = true)
#  |    |    |    |    |    |-- second: double (nullable = true)
#  |    |    |    |    |-- scalePDF: double (nullable = true)
#  |-- GenEventInfoProduct_generator__SIM_: struct (nullable = true)
#  |    |-- present: boolean (nullable = true)
#  |    |-- GenEventInfoProduct_generator__SIM_obj: struct (nullable = true)
#  |    |    |-- weights_: array (nullable = true)
#  |    |    |    |-- element: double (containsNull = true)
#  |    |    |-- signalProcessID_: integer (nullable = true)
#  |    |    |-- qScale_: double (nullable = true)
#  |    |    |-- alphaQCD_: double (nullable = true)
#  |    |    |-- alphaQED_: double (nullable = true)
#  |    |    |-- pdf_: struct (nullable = true)
#  |    |    |    |-- _M_ptr: struct (nullable = true)
#  |    |    |    |    |-- id: struct (nullable = true)
#  |    |    |    |    |    |-- first: integer (nullable = true)
#  |    |    |    |    |    |-- second: integer (nullable = true)
#  |    |    |    |    |-- x: struct (nullable = true)
#  |    |    |    |    |    |-- first: double (nullable = true)
#  |    |    |    |    |    |-- second: double (nullable = true)
#  |    |    |    |    |-- xPDF: struct (nullable = true)
#  |    |    |    |    |    |-- first: double (nullable = true)
#  |    |    |    |    |    |-- second: double (nullable = true)
#  |    |    |    |    |-- scalePDF: double (nullable = true)
#  |    |    |-- binningValues_: array (nullable = true)
#  |    |    |    |-- element: double (containsNull = true)
#  |-- edmTriggerResults_TriggerResults__SIM_: struct (nullable = true)
#  |    |-- present: boolean (nullable = true)
#  |    |-- edmTriggerResults_TriggerResults__SIM_obj: struct (nullable = true)
#  |    |    |-- edm__HLTGlobalStatus: struct (nullable = true)
#  |    |    |    |-- paths_: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- status_: short (nullable = true)
#  |    |    |-- psetid_: struct (nullable = true)
#  |    |    |    |-- hash_: string (nullable = true)
#  |    |    |-- names_: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |-- ints_genParticles__SIM_: struct (nullable = true)
#  |    |-- present: boolean (nullable = true)
#  |    |-- ints_genParticles__SIM_obj: array (nullable = true)
#  |    |    |-- element: integer (containsNull = true)
#  |-- recoGenJets_ak5GenJets__SIM_: struct (nullable = true)
#  |    |-- present: boolean (nullable = true)
#  |    |-- recoGenJets_ak5GenJets__SIM_obj: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- reco__Jet: struct (nullable = true)
#  |    |    |    |    |-- reco__CompositePtrCandidate: struct (nullable = true)
#  |    |    |    |    |    |-- reco__LeafCandidate: struct (nullable = true)
#  |    |    |    |    |    |    |-- qx3_: integer (nullable = true)
#  |    |    |    |    |    |    |-- pt_: float (nullable = true)
#  |    |    |    |    |    |    |-- eta_: float (nullable = true)
#  |    |    |    |    |    |    |-- phi_: float (nullable = true)
#  |    |    |    |    |    |    |-- mass_: float (nullable = true)
#  |    |    |    |    |    |    |-- vertex_: struct (nullable = true)
#  |    |    |    |    |    |    |    |-- fCoordinates: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |-- fX: float (nullable = true)
#  |    |    |    |    |    |    |    |    |-- fY: float (nullable = true)
#  |    |    |    |    |    |    |    |    |-- fZ: float (nullable = true)
#  |    |    |    |    |    |    |-- pdgId_: integer (nullable = true)
#  |    |    |    |    |    |    |-- status_: integer (nullable = true)
#  |    |    |    |    |    |-- dau: array (nullable = true)
#  |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |-- core_: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |-- processIndex_: short (nullable = true)
#  |    |    |    |    |    |    |    |    |-- productIndex_: short (nullable = true)
#  |    |    |    |    |    |    |    |-- key_: long (nullable = true)
#  |    |    |    |    |-- mJetArea: float (nullable = true)
#  |    |    |    |    |-- mPileupEnergy: float (nullable = true)
#  |    |    |    |    |-- mPassNumber: integer (nullable = true)
#  |    |    |    |-- m_specific: struct (nullable = true)
#  |    |    |    |    |-- m_EmEnergy: float (nullable = true)
#  |    |    |    |    |-- m_HadEnergy: float (nullable = true)
#  |    |    |    |    |-- m_InvisibleEnergy: float (nullable = true)
#  |    |    |    |    |-- m_AuxiliaryEnergy: float (nullable = true)
#  |-- recoGenJets_ak7GenJets__SIM_: struct (nullable = true)
#  |    |-- present: boolean (nullable = true)
#  |    |-- recoGenJets_ak7GenJets__SIM_obj: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- reco__Jet: struct (nullable = true)
#  |    |    |    |    |-- reco__CompositePtrCandidate: struct (nullable = true)
#  |    |    |    |    |    |-- reco__LeafCandidate: struct (nullable = true)
#  |    |    |    |    |    |    |-- qx3_: integer (nullable = true)
#  |    |    |    |    |    |    |-- pt_: float (nullable = true)
#  |    |    |    |    |    |    |-- eta_: float (nullable = true)
#  |    |    |    |    |    |    |-- phi_: float (nullable = true)
#  |    |    |    |    |    |    |-- mass_: float (nullable = true)
#  |    |    |    |    |    |    |-- vertex_: struct (nullable = true)
#  |    |    |    |    |    |    |    |-- fCoordinates: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |-- fX: float (nullable = true)
#  |    |    |    |    |    |    |    |    |-- fY: float (nullable = true)
#  |    |    |    |    |    |    |    |    |-- fZ: float (nullable = true)
#  |    |    |    |    |    |    |-- pdgId_: integer (nullable = true)
#  |    |    |    |    |    |    |-- status_: integer (nullable = true)
#  |    |    |    |    |    |-- dau: array (nullable = true)
#  |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |-- core_: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |-- processIndex_: short (nullable = true)
#  |    |    |    |    |    |    |    |    |-- productIndex_: short (nullable = true)
#  |    |    |    |    |    |    |    |-- key_: long (nullable = true)
#  |    |    |    |    |-- mJetArea: float (nullable = true)
#  |    |    |    |    |-- mPileupEnergy: float (nullable = true)
#  |    |    |    |    |-- mPassNumber: integer (nullable = true)
#  |    |    |    |-- m_specific: struct (nullable = true)
#  |    |    |    |    |-- m_EmEnergy: float (nullable = true)
#  |    |    |    |    |-- m_HadEnergy: float (nullable = true)
#  |    |    |    |    |-- m_InvisibleEnergy: float (nullable = true)
#  |    |    |    |    |-- m_AuxiliaryEnergy: float (nullable = true)
#  |-- recoGenJets_kt4GenJets__SIM_: struct (nullable = true)
#  |    |-- present: boolean (nullable = true)
#  |    |-- recoGenJets_kt4GenJets__SIM_obj: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- reco__Jet: struct (nullable = true)
#  |    |    |    |    |-- reco__CompositePtrCandidate: struct (nullable = true)
#  |    |    |    |    |    |-- reco__LeafCandidate: struct (nullable = true)
#  |    |    |    |    |    |    |-- qx3_: integer (nullable = true)
#  |    |    |    |    |    |    |-- pt_: float (nullable = true)
#  |    |    |    |    |    |    |-- eta_: float (nullable = true)
#  |    |    |    |    |    |    |-- phi_: float (nullable = true)
#  |    |    |    |    |    |    |-- mass_: float (nullable = true)
#  |    |    |    |    |    |    |-- vertex_: struct (nullable = true)
#  |    |    |    |    |    |    |    |-- fCoordinates: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |-- fX: float (nullable = true)
#  |    |    |    |    |    |    |    |    |-- fY: float (nullable = true)
#  |    |    |    |    |    |    |    |    |-- fZ: float (nullable = true)
#  |    |    |    |    |    |    |-- pdgId_: integer (nullable = true)
#  |    |    |    |    |    |    |-- status_: integer (nullable = true)
#  |    |    |    |    |    |-- dau: array (nullable = true)
#  |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |-- core_: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |-- processIndex_: short (nullable = true)
#  |    |    |    |    |    |    |    |    |-- productIndex_: short (nullable = true)
#  |    |    |    |    |    |    |    |-- key_: long (nullable = true)
#  |    |    |    |    |-- mJetArea: float (nullable = true)
#  |    |    |    |    |-- mPileupEnergy: float (nullable = true)
#  |    |    |    |    |-- mPassNumber: integer (nullable = true)
#  |    |    |    |-- m_specific: struct (nullable = true)
#  |    |    |    |    |-- m_EmEnergy: float (nullable = true)
#  |    |    |    |    |-- m_HadEnergy: float (nullable = true)
#  |    |    |    |    |-- m_InvisibleEnergy: float (nullable = true)
#  |    |    |    |    |-- m_AuxiliaryEnergy: float (nullable = true)
#  |-- recoGenJets_kt6GenJets__SIM_: struct (nullable = true)
#  |    |-- present: boolean (nullable = true)
#  |    |-- recoGenJets_kt6GenJets__SIM_obj: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- reco__Jet: struct (nullable = true)
#  |    |    |    |    |-- reco__CompositePtrCandidate: struct (nullable = true)
#  |    |    |    |    |    |-- reco__LeafCandidate: struct (nullable = true)
#  |    |    |    |    |    |    |-- qx3_: integer (nullable = true)
#  |    |    |    |    |    |    |-- pt_: float (nullable = true)
#  |    |    |    |    |    |    |-- eta_: float (nullable = true)
#  |    |    |    |    |    |    |-- phi_: float (nullable = true)
#  |    |    |    |    |    |    |-- mass_: float (nullable = true)
#  |    |    |    |    |    |    |-- vertex_: struct (nullable = true)
#  |    |    |    |    |    |    |    |-- fCoordinates: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |-- fX: float (nullable = true)
#  |    |    |    |    |    |    |    |    |-- fY: float (nullable = true)
#  |    |    |    |    |    |    |    |    |-- fZ: float (nullable = true)
#  |    |    |    |    |    |    |-- pdgId_: integer (nullable = true)
#  |    |    |    |    |    |    |-- status_: integer (nullable = true)
#  |    |    |    |    |    |-- dau: array (nullable = true)
#  |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |-- core_: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |-- processIndex_: short (nullable = true)
#  |    |    |    |    |    |    |    |    |-- productIndex_: short (nullable = true)
#  |    |    |    |    |    |    |    |-- key_: long (nullable = true)
#  |    |    |    |    |-- mJetArea: float (nullable = true)
#  |    |    |    |    |-- mPileupEnergy: float (nullable = true)
#  |    |    |    |    |-- mPassNumber: integer (nullable = true)
#  |    |    |    |-- m_specific: struct (nullable = true)
#  |    |    |    |    |-- m_EmEnergy: float (nullable = true)
#  |    |    |    |    |-- m_HadEnergy: float (nullable = true)
#  |    |    |    |    |-- m_InvisibleEnergy: float (nullable = true)
#  |    |    |    |    |-- m_AuxiliaryEnergy: float (nullable = true)
#  |-- recoGenMETs_genMetCalo__SIM_: struct (nullable = true)
#  |    |-- present: boolean (nullable = true)
#  |    |-- recoGenMETs_genMetCalo__SIM_obj: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- reco__MET: struct (nullable = true)
#  |    |    |    |    |-- reco__RecoCandidate: struct (nullable = true)
#  |    |    |    |    |    |-- reco__LeafCandidate: struct (nullable = true)
#  |    |    |    |    |    |    |-- qx3_: integer (nullable = true)
#  |    |    |    |    |    |    |-- pt_: float (nullable = true)
#  |    |    |    |    |    |    |-- eta_: float (nullable = true)
#  |    |    |    |    |    |    |-- phi_: float (nullable = true)
#  |    |    |    |    |    |    |-- mass_: float (nullable = true)
#  |    |    |    |    |    |    |-- vertex_: struct (nullable = true)
#  |    |    |    |    |    |    |    |-- fCoordinates: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |-- fX: float (nullable = true)
#  |    |    |    |    |    |    |    |    |-- fY: float (nullable = true)
#  |    |    |    |    |    |    |    |    |-- fZ: float (nullable = true)
#  |    |    |    |    |    |    |-- pdgId_: integer (nullable = true)
#  |    |    |    |    |    |    |-- status_: integer (nullable = true)
#  |    |    |    |    |-- sumet: double (nullable = true)
#  |    |    |    |    |-- elongit: double (nullable = true)
#  |    |    |    |    |-- signif_dxx: double (nullable = true)
#  |    |    |    |    |-- signif_dyy: double (nullable = true)
#  |    |    |    |    |-- signif_dyx: double (nullable = true)
#  |    |    |    |    |-- signif_dxy: double (nullable = true)
#  |    |    |    |    |-- corr: array (nullable = true)
#  |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |-- mex: double (nullable = true)
#  |    |    |    |    |    |    |-- mey: double (nullable = true)
#  |    |    |    |    |    |    |-- sumet: double (nullable = true)
#  |    |    |    |    |    |    |-- significance: double (nullable = true)
#  |    |    |    |-- gen_data: struct (nullable = true)
#  |    |    |    |    |-- NeutralEMEtFraction: double (nullable = true)
#  |    |    |    |    |-- NeutralHadEtFraction: double (nullable = true)
#  |    |    |    |    |-- ChargedEMEtFraction: double (nullable = true)
#  |    |    |    |    |-- ChargedHadEtFraction: double (nullable = true)
#  |    |    |    |    |-- MuonEtFraction: double (nullable = true)
#  |    |    |    |    |-- InvisibleEtFraction: double (nullable = true)
#  |    |    |    |    |-- m_EmEnergy: double (nullable = true)
#  |    |    |    |    |-- m_HadEnergy: double (nullable = true)
#  |    |    |    |    |-- m_InvisibleEnergy: double (nullable = true)
#  |    |    |    |    |-- m_AuxiliaryEnergy: double (nullable = true)
#  |-- recoGenMETs_genMetCaloAndNonPrompt__SIM_: struct (nullable = true)
#  |    |-- present: boolean (nullable = true)
#  |    |-- recoGenMETs_genMetCaloAndNonPrompt__SIM_obj: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- reco__MET: struct (nullable = true)
#  |    |    |    |    |-- reco__RecoCandidate: struct (nullable = true)
#  |    |    |    |    |    |-- reco__LeafCandidate: struct (nullable = true)
#  |    |    |    |    |    |    |-- qx3_: integer (nullable = true)
#  |    |    |    |    |    |    |-- pt_: float (nullable = true)
#  |    |    |    |    |    |    |-- eta_: float (nullable = true)
#  |    |    |    |    |    |    |-- phi_: float (nullable = true)
#  |    |    |    |    |    |    |-- mass_: float (nullable = true)
#  |    |    |    |    |    |    |-- vertex_: struct (nullable = true)
#  |    |    |    |    |    |    |    |-- fCoordinates: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |-- fX: float (nullable = true)
#  |    |    |    |    |    |    |    |    |-- fY: float (nullable = true)
#  |    |    |    |    |    |    |    |    |-- fZ: float (nullable = true)
#  |    |    |    |    |    |    |-- pdgId_: integer (nullable = true)
#  |    |    |    |    |    |    |-- status_: integer (nullable = true)
#  |    |    |    |    |-- sumet: double (nullable = true)
#  |    |    |    |    |-- elongit: double (nullable = true)
#  |    |    |    |    |-- signif_dxx: double (nullable = true)
#  |    |    |    |    |-- signif_dyy: double (nullable = true)
#  |    |    |    |    |-- signif_dyx: double (nullable = true)
#  |    |    |    |    |-- signif_dxy: double (nullable = true)
#  |    |    |    |    |-- corr: array (nullable = true)
#  |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |-- mex: double (nullable = true)
#  |    |    |    |    |    |    |-- mey: double (nullable = true)
#  |    |    |    |    |    |    |-- sumet: double (nullable = true)
#  |    |    |    |    |    |    |-- significance: double (nullable = true)
#  |    |    |    |-- gen_data: struct (nullable = true)
#  |    |    |    |    |-- NeutralEMEtFraction: double (nullable = true)
#  |    |    |    |    |-- NeutralHadEtFraction: double (nullable = true)
#  |    |    |    |    |-- ChargedEMEtFraction: double (nullable = true)
#  |    |    |    |    |-- ChargedHadEtFraction: double (nullable = true)
#  |    |    |    |    |-- MuonEtFraction: double (nullable = true)
#  |    |    |    |    |-- InvisibleEtFraction: double (nullable = true)
#  |    |    |    |    |-- m_EmEnergy: double (nullable = true)
#  |    |    |    |    |-- m_HadEnergy: double (nullable = true)
#  |    |    |    |    |-- m_InvisibleEnergy: double (nullable = true)
#  |    |    |    |    |-- m_AuxiliaryEnergy: double (nullable = true)
#  |-- recoGenMETs_genMetTrue__SIM_: struct (nullable = true)
#  |    |-- present: boolean (nullable = true)
#  |    |-- recoGenMETs_genMetTrue__SIM_obj: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- reco__MET: struct (nullable = true)
#  |    |    |    |    |-- reco__RecoCandidate: struct (nullable = true)
#  |    |    |    |    |    |-- reco__LeafCandidate: struct (nullable = true)
#  |    |    |    |    |    |    |-- qx3_: integer (nullable = true)
#  |    |    |    |    |    |    |-- pt_: float (nullable = true)
#  |    |    |    |    |    |    |-- eta_: float (nullable = true)
#  |    |    |    |    |    |    |-- phi_: float (nullable = true)
#  |    |    |    |    |    |    |-- mass_: float (nullable = true)
#  |    |    |    |    |    |    |-- vertex_: struct (nullable = true)
#  |    |    |    |    |    |    |    |-- fCoordinates: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |-- fX: float (nullable = true)
#  |    |    |    |    |    |    |    |    |-- fY: float (nullable = true)
#  |    |    |    |    |    |    |    |    |-- fZ: float (nullable = true)
#  |    |    |    |    |    |    |-- pdgId_: integer (nullable = true)
#  |    |    |    |    |    |    |-- status_: integer (nullable = true)
#  |    |    |    |    |-- sumet: double (nullable = true)
#  |    |    |    |    |-- elongit: double (nullable = true)
#  |    |    |    |    |-- signif_dxx: double (nullable = true)
#  |    |    |    |    |-- signif_dyy: double (nullable = true)
#  |    |    |    |    |-- signif_dyx: double (nullable = true)
#  |    |    |    |    |-- signif_dxy: double (nullable = true)
#  |    |    |    |    |-- corr: array (nullable = true)
#  |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |-- mex: double (nullable = true)
#  |    |    |    |    |    |    |-- mey: double (nullable = true)
#  |    |    |    |    |    |    |-- sumet: double (nullable = true)
#  |    |    |    |    |    |    |-- significance: double (nullable = true)
#  |    |    |    |-- gen_data: struct (nullable = true)
#  |    |    |    |    |-- NeutralEMEtFraction: double (nullable = true)
#  |    |    |    |    |-- NeutralHadEtFraction: double (nullable = true)
#  |    |    |    |    |-- ChargedEMEtFraction: double (nullable = true)
#  |    |    |    |    |-- ChargedHadEtFraction: double (nullable = true)
#  |    |    |    |    |-- MuonEtFraction: double (nullable = true)
#  |    |    |    |    |-- InvisibleEtFraction: double (nullable = true)
#  |    |    |    |    |-- m_EmEnergy: double (nullable = true)
#  |    |    |    |    |-- m_HadEnergy: double (nullable = true)
#  |    |    |    |    |-- m_InvisibleEnergy: double (nullable = true)
#  |    |    |    |    |-- m_AuxiliaryEnergy: double (nullable = true)
#  |-- recoGenParticles_genParticles__SIM_: struct (nullable = true)
#  |    |-- present: boolean (nullable = true)
#  |    |-- recoGenParticles_genParticles__SIM_obj: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- reco__CompositeRefCandidateT<edm__RefVector<vector<reco__GenParticle>,reco__GenParticle,edm__refhelper__FindUsingAdvance<vector<reco__GenParticle>,reco__GenParticle> > >: struct (nullable = true)
#  |    |    |    |    |-- reco__LeafCandidate: struct (nullable = true)
#  |    |    |    |    |    |-- qx3_: integer (nullable = true)
#  |    |    |    |    |    |-- pt_: float (nullable = true)
#  |    |    |    |    |    |-- eta_: float (nullable = true)
#  |    |    |    |    |    |-- phi_: float (nullable = true)
#  |    |    |    |    |    |-- mass_: float (nullable = true)
#  |    |    |    |    |    |-- vertex_: struct (nullable = true)
#  |    |    |    |    |    |    |-- fCoordinates: struct (nullable = true)
#  |    |    |    |    |    |    |    |-- fX: float (nullable = true)
#  |    |    |    |    |    |    |    |-- fY: float (nullable = true)
#  |    |    |    |    |    |    |    |-- fZ: float (nullable = true)
#  |    |    |    |    |    |-- pdgId_: integer (nullable = true)
#  |    |    |    |    |    |-- status_: integer (nullable = true)
#  |    |    |    |    |-- dau: struct (nullable = true)
#  |    |    |    |    |    |-- refVector_: struct (nullable = true)
#  |    |    |    |    |    |    |-- product_: struct (nullable = true)
#  |    |    |    |    |    |    |    |-- processIndex_: short (nullable = true)
#  |    |    |    |    |    |    |    |-- productIndex_: short (nullable = true)
#  |    |    |    |    |    |    |-- keys_: array (nullable = true)
#  |    |    |    |    |    |    |    |-- element: integer (containsNull = true)
#  |    |    |    |    |-- mom: struct (nullable = true)
#  |    |    |    |    |    |-- refVector_: struct (nullable = true)
#  |    |    |    |    |    |    |-- product_: struct (nullable = true)
#  |    |    |    |    |    |    |    |-- processIndex_: short (nullable = true)
#  |    |    |    |    |    |    |    |-- productIndex_: short (nullable = true)
#  |    |    |    |    |    |    |-- keys_: array (nullable = true)
#  |    |    |    |    |    |    |    |-- element: integer (containsNull = true)
#  |    |    |    |-- collisionId_: integer (nullable = true)
#  |-- edmTriggerResults_TriggerResults__HLT_: struct (nullable = true)
#  |    |-- present: boolean (nullable = true)
#  |    |-- edmTriggerResults_TriggerResults__HLT_obj: struct (nullable = true)
#  |    |    |-- edm__HLTGlobalStatus: struct (nullable = true)
#  |    |    |    |-- paths_: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- status_: short (nullable = true)
#  |    |    |-- psetid_: struct (nullable = true)
#  |    |    |    |-- hash_: string (nullable = true)
#  |    |    |-- names_: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |-- PileupSummaryInfos_addPileupInfo__HLT_: struct (nullable = true)
#  |    |-- present: boolean (nullable = true)
#  |    |-- PileupSummaryInfos_addPileupInfo__HLT_obj: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- num_PU_vertices_: integer (nullable = true)
#  |    |    |    |-- zpositions_: array (nullable = true)
#  |    |    |    |    |-- element: float (containsNull = true)
#  |    |    |    |-- sumpT_lowpT_: array (nullable = true)
#  |    |    |    |    |-- element: float (containsNull = true)
#  |    |    |    |-- sumpT_highpT_: array (nullable = true)
#  |    |    |    |    |-- element: float (containsNull = true)
#  |    |    |    |-- ntrks_lowpT_: array (nullable = true)
#  |    |    |    |    |-- element: integer (containsNull = true)
#  |    |    |    |-- ntrks_highpT_: array (nullable = true)
#  |    |    |    |    |-- element: integer (containsNull = true)
#  |    |    |    |-- bunchCrossing_: integer (nullable = true)
#  |    |    |    |-- TrueNumInteractions_: float (nullable = true)
#  |    |    |    |-- instLumi_: array (nullable = true)
#  |    |    |    |    |-- element: float (containsNull = true)
#  |    |    |    |-- eventInfo_: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- run_: integer (nullable = true)
#  |    |    |    |    |    |-- luminosityBlock_: integer (nullable = true)
#  |    |    |    |    |    |-- event_: integer (nullable = true)
#  |-- triggerTriggerEvent_hltTriggerSummaryAOD__HLT_: struct (nullable = true)
#  |    |-- present: boolean (nullable = true)
#  |    |-- triggerTriggerEvent_hltTriggerSummaryAOD__HLT_obj: struct (nullable = true)
#  |    |    |-- usedProcessName_: string (nullable = true)
#  |    |    |-- collectionTags_: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- collectionKeys_: array (nullable = true)
#  |    |    |    |-- element: short (containsNull = true)
#  |    |    |-- triggerObjects_: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- id_: integer (nullable = true)
#  |    |    |    |    |-- pt_: float (nullable = true)
#  |    |    |    |    |-- eta_: float (nullable = true)
#  |    |    |    |    |-- phi_: float (nullable = true)
#  |    |    |    |    |-- mass_: float (nullable = true)
#  |    |    |-- triggerFilters_: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- filterTag_: string (nullable = true)
#  |    |    |    |    |-- filterIds_: array (nullable = true)
#  |    |    |    |    |    |-- element: integer (containsNull = true)
#  |    |    |    |    |-- filterKeys_: array (nullable = true)
#  |    |    |    |    |    |-- element: short (containsNull = true)
#  |-- ClusterSummary_clusterSummaryProducer__RECO_: struct (nullable = true)
#  |    |-- present: boolean (nullable = true)
#  |    |-- ClusterSummary_clusterSummaryProducer__RECO_obj: struct (nullable = true)
#  |    |    |-- ClusterSummary_clusterSummaryProducer__RECO_obj_iterator_: array (nullable = true)
#  |    |    |    |-- element: integer (containsNull = true)
#  |    |    |-- ClusterSummary_clusterSummaryProducer__RECO_obj_modules_: array (nullable = true)
#  |    |    |    |-- element: integer (containsNull = true)
#  |    |    |-- ClusterSummary_clusterSummaryProducer__RECO_obj_genericVariables_: array (nullable = true)
#  |    |    |    |-- element: array (containsNull = true)
#  |    |    |    |    |-- element: double (containsNull = true)
#  |-- EBDigiCollection_selectDigi_selectedEcalEBDigiCollection_RECO_: struct (nullable = true)
#  |    |-- present: boolean (nullable = true)
#  |    |-- EBDigiCollection_selectDigi_selectedEcalEBDigiCollection_RECO_obj: struct (nullable = true)
#  |    |    |-- EBDigiCollection_selectDigi_selectedEcalEBDigiCollection_RECO_obj_EcalDigiCollection: struct (nullable = true)
#  |    |    |    |-- EBDigiCollection_selectDigi_selectedEcalEBDigiCollection_RECO_obj_edm__DataFrameContainer: struct (nullable = true)
#  |    |    |    |    |-- m_subdetId: integer (nullable = true)
#  |    |    |    |    |-- m_stride: integer (nullable = true)
#  |    |    |    |    |-- EBDigiCollection_selectDigi_selectedEcalEBDigiCollection_RECO_obj_m_ids: array (nullable = true)
#  |    |    |    |    |    |-- element: integer (containsNull = true)
#  |    |    |    |    |-- EBDigiCollection_selectDigi_selectedEcalEBDigiCollection_RECO_obj_m_data: array (nullable = true)
#  |    |    |    |    |    |-- element: short (containsNull = true)
#  |-- EEDigiCollection_selectDigi_selectedEcalEEDigiCollection_RECO_: struct (nullable = true)
#  |    |-- present: boolean (nullable = true)
#  |    |-- EEDigiCollection_selectDigi_selectedEcalEEDigiCollection_RECO_obj: struct (nullable = true)
#  |    |    |-- EEDigiCollection_selectDigi_selectedEcalEEDigiCollection_RECO_obj_EcalDigiCollection: struct (nullable = true)
#  |    |    |    |-- EEDigiCollection_selectDigi_selectedEcalEEDigiCollection_RECO_obj_edm__DataFrameContainer: struct (nullable = true)
#  |    |    |    |    |-- m_subdetId: integer (nullable = true)
#  |    |    |    |    |-- m_stride: integer (nullable = true)
#  |    |    |    |    |-- EEDigiCollection_selectDigi_selectedEcalEEDigiCollection_RECO_obj_m_ids: array (nullable = true)
#  |    |    |    |    |    |-- element: integer (containsNull = true)
#  |    |    |    |    |-- EEDigiCollection_selectDigi_selectedEcalEEDigiCollection_RECO_obj_m_data: array (nullable = true)
#  |    |    |    |    |    |-- element: short (containsNull = true)
#  |-- HcalNoiseSummary_hcalnoise__RECO_: struct (nullable = true)
#  |    |-- present: boolean (nullable = true)
#  |    |-- HcalNoiseSummary_hcalnoise__RECO_obj: struct (nullable = true)
#  |    |    |-- filterstatus_: integer (nullable = true)
#  |    |    |-- noisetype_: integer (nullable = true)
#  |    |    |-- emenergy_: float (nullable = true)
#  |    |    |-- hadenergy_: float (nullable = true)
#  |    |    |-- trackenergy_: float (nullable = true)
#  |    |    |-- min10_: float (nullable = true)
#  |    |    |-- max10_: float (nullable = true)
#  |    |    |-- rms10_: float (nullable = true)
#  |    |    |-- min25_: float (nullable = true)
#  |    |    |-- max25_: float (nullable = true)
#  |    |    |-- rms25_: float (nullable = true)
#  |    |    |-- cnthit10_: integer (nullable = true)
#  |    |    |-- cnthit25_: integer (nullable = true)
#  |    |    |-- mine2ts_: float (nullable = true)
#  |    |    |-- mine10ts_: float (nullable = true)
#  |    |    |-- maxe2ts_: float (nullable = true)
#  |    |    |-- maxe10ts_: float (nullable = true)
#  |    |    |-- maxzeros_: integer (nullable = true)
#  |    |    |-- maxhpdhits_: integer (nullable = true)
#  |    |    |-- maxhpdhitsnoother_: integer (nullable = true)
#  |    |    |-- maxrbxhits_: integer (nullable = true)
#  |    |    |-- minhpdemf_: float (nullable = true)
#  |    |    |-- minrbxemf_: float (nullable = true)
#  |    |    |-- nproblemRBXs_: integer (nullable = true)
#  |    |    |-- nisolnoise_: integer (nullable = true)
#  |    |    |-- isolnoisee_: float (nullable = true)
#  |    |    |-- isolnoiseet_: float (nullable = true)
#  |    |    |-- nflatnoise_: integer (nullable = true)
#  |    |    |-- flatnoisee_: float (nullable = true)
#  |    |    |-- flatnoiseet_: float (nullable = true)
#  |    |    |-- nspikenoise_: integer (nullable = true)
#  |    |    |-- spikenoisee_: float (nullable = true)
#  |    |    |-- spikenoiseet_: float (nullable = true)
#  |    |    |-- ntrianglenoise_: integer (nullable = true)
#  |    |    |-- trianglenoisee_: float (nullable = true)
#  |    |    |-- trianglenoiseet_: float (nullable = true)
#  |    |    |-- nts4ts5noise_: integer (nullable = true)
#  |    |    |-- ts4ts5noisee_: float (nullable = true)
#  |    |    |-- ts4ts5noiseet_: float (nullable = true)
#  |    |    |-- rechitCount_: integer (nullable = true)
#  |    |    |-- rechitCount15_: integer (nullable = true)
#  |    |    |-- rechitEnergy_: double (nullable = true)
#  |    |    |-- rechitEnergy15_: double (nullable = true)
#  |    |    |-- calibCharge_: double (nullable = true)
#  |    |    |-- hasBadRBXTS4TS5_: boolean (nullable = true)
#  |    |    |-- problemjets_: struct (nullable = true)
#  |    |    |    |-- refVector_: struct (nullable = true)
#  |    |    |    |    |-- HcalNoiseSummary_hcalnoise__RECO_obj_problemjets__refVector__product_: struct (nullable = true)
#  |    |    |    |    |    |-- processIndex_: short (nullable = true)
#  |    |    |    |    |    |-- productIndex_: short (nullable = true)
#  |    |    |    |    |-- HcalNoiseSummary_hcalnoise__RECO_obj_problemjets__refVector__keys_: array (nullable = true)
#  |    |    |    |    |    |-- element: integer (containsNull = true)
#  |    |    |-- loosenoisetwrs_: struct (nullable = true)
#  |    |    |    |-- refVector_: struct (nullable = true)
#  |    |    |    |    |-- HcalNoiseSummary_hcalnoise__RECO_obj_loosenoisetwrs__refVector__product_: struct (nullable = true)
#  |    |    |    |    |    |-- processIndex_: short (nullable = true)
#  |    |    |    |    |    |-- productIndex_: short (nullable = true)
#  |    |    |    |    |-- HcalNoiseSummary_hcalnoise__RECO_obj_loosenoisetwrs__refVector__keys_: array (nullable = true)
#  |    |    |    |    |    |-- element: integer (containsNull = true)
#  |    |    |-- tightnoisetwrs_: struct (nullable = true)
#  |    |    |    |-- refVector_: struct (nullable = true)
#  |    |    |    |    |-- HcalNoiseSummary_hcalnoise__RECO_obj_tightnoisetwrs__refVector__product_: struct (nullable = true)
#  |    |    |    |    |    |-- processIndex_: short (nullable = true)
#  |    |    |    |    |    |-- productIndex_: short (nullable = true)
#  |    |    |    |    |-- HcalNoiseSummary_hcalnoise__RECO_obj_tightnoisetwrs__refVector__keys_: array (nullable = true)
#  |    |    |    |    |    |-- element: integer (containsNull = true)
#  |    |    |-- hlnoisetwrs_: struct (nullable = true)
#  |    |    |    |-- refVector_: struct (nullable = true)
#  |    |    |    |    |-- HcalNoiseSummary_hcalnoise__RECO_obj_hlnoisetwrs__refVector__product_: struct (nullable = true)
#  |    |    |    |    |    |-- processIndex_: short (nullable = true)
#  |    |    |    |    |    |-- productIndex_: short (nullable = true)
#  |    |    |    |    |-- HcalNoiseSummary_hcalnoise__RECO_obj_hlnoisetwrs__refVector__keys_: array (nullable = true)
#  |    |    |    |    |    |-- element: integer (containsNull = true)
#  |-- HcalUnpackerReport_castorDigis__RECO_: struct (nullable = true)
#  |    |-- present: boolean (nullable = true)
#  |    |-- HcalUnpackerReport_castorDigis__RECO_obj: struct (nullable = true)
#  |    |    |-- HcalUnpackerReport_castorDigis__RECO_obj_FEDsUnpacked_: array (nullable = true)
#  |    |    |    |-- element: integer (containsNull = true)
#  |    |    |-- HcalUnpackerReport_castorDigis__RECO_obj_FEDsError_: array (nullable = true)
#  |    |    |    |-- element: integer (containsNull = true)
#  |    |    |-- unmappedDigis_: integer (nullable = true)
#  |    |    |-- unmappedTPDigis_: integer (nullable = true)
#  |    |    |-- spigotFormatErrors_: integer (nullable = true)
#  |    |    |-- badqualityDigis_: integer (nullable = true)
#  |    |    |-- totalDigis_: integer (nullable = true)
#  |    |    |-- totalTPDigis_: integer (nullable = true)
#  |    |    |-- totalHOTPDigis_: integer (nullable = true)
#  |    |    |-- HcalUnpackerReport_castorDigis__RECO_obj_badqualityIds_: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- id_: integer (nullable = true)
#  |    |    |-- HcalUnpackerReport_castorDigis__RECO_obj_unmappedIds_: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- hcalElectronicsId_: integer (nullable = true)
#  |    |    |-- unsuppressed_: boolean (nullable = true)
#  |    |    |-- HcalUnpackerReport_castorDigis__RECO_obj_reportInfo_: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- HcalUnpackerReport_castorDigis__RECO_obj_fedInfo_: array (nullable = true)
#  |    |    |    |-- element: short (containsNull = true)
#  |    |    |-- emptyEventSpigots_: integer (nullable = true)
#  |    |    |-- ofwSpigots_: integer (nullable = true)
#  |    |    |-- busySpigots_: integer (nullable = true)
#  |-- HcalUnpackerReport_hcalDigis__RECO_: struct (nullable = true)
#  |    |-- present: boolean (nullable = true)
#  |    |-- HcalUnpackerReport_hcalDigis__RECO_obj: struct (nullable = true)
#  |    |    |-- HcalUnpackerReport_hcalDigis__RECO_obj_FEDsUnpacked_: array (nullable = true)
#  |    |    |    |-- element: integer (containsNull = true)
#  |    |    |-- HcalUnpackerReport_hcalDigis__RECO_obj_FEDsError_: array (nullable = true)
#  |    |    |    |-- element: integer (containsNull = true)
#  |    |    |-- unmappedDigis_: integer (nullable = true)
#  |    |    |-- unmappedTPDigis_: integer (nullable = true)
#  |    |    |-- spigotFormatErrors_: integer (nullable = true)
#  |    |    |-- badqualityDigis_: integer (nullable = true)
#  |    |    |-- totalDigis_: integer (nullable = true)
#  |    |    |-- totalTPDigis_: integer (nullable = true)
#  |    |    |-- totalHOTPDigis_: integer (nullable = true)
#  |    |    |-- HcalUnpackerReport_hcalDigis__RECO_obj_badqualityIds_: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- id_: integer (nullable = true)
#  |    |    |-- HcalUnpackerReport_hcalDigis__RECO_obj_unmappedIds_: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- hcalElectronicsId_: integer (nullable = true)
#  |    |    |-- unsuppressed_: boolean (nullable = true)
#  |    |    |-- HcalUnpackerReport_hcalDigis__RECO_obj_reportInfo_: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- HcalUnpackerReport_hcalDigis__RECO_obj_fedInfo_: array (nullable = true)
#  |    |    |    |-- element: short (containsNull = true)
#  |    |    |-- emptyEventSpigots_: integer (nullable = true)
#  |    |    |-- ofwSpigots_: integer (nullable = true)
#  |    |    |-- busySpigots_: integer (nullable = true)
#  |-- L1GlobalTriggerObjectMaps_l1L1GtObjectMap__RECO_: struct (nullable = true)
#  |    |-- present: boolean (nullable = true)
#  |    |-- L1GlobalTriggerObjectMaps_l1L1GtObjectMap__RECO_obj: struct (nullable = true)
#  |    |    |-- L1GlobalTriggerObjectMaps_l1L1GtObjectMap__RECO_obj_m_algorithmResults: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- m_startIndexOfConditions: integer (nullable = true)
#  |    |    |    |    |-- m_algorithmBitNumber: short (nullable = true)
#  |    |    |    |    |-- m_algorithmResult: boolean (nullable = true)
#  |    |    |-- L1GlobalTriggerObjectMaps_l1L1GtObjectMap__RECO_obj_m_conditionResults: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- m_startIndexOfCombinations: integer (nullable = true)
#  |    |    |    |    |-- m_nObjectsPerCombination: short (nullable = true)
#  |    |    |    |    |-- m_conditionResult: boolean (nullable = true)
#  |    |    |-- L1GlobalTriggerObjectMaps_l1L1GtObjectMap__RECO_obj_m_combinations: array (nullable = true)
#  |    |    |    |-- element: byte (containsNull = true)
#  |    |    |-- m_namesParameterSetID: struct (nullable = true)
#  |    |    |    |-- hash_: string (nullable = true)
#  |-- L1GlobalTriggerReadoutRecord_gtDigis__RECO_: struct (nullable = true)
#  |    |-- present: boolean (nullable = true)
#  |    |-- L1GlobalTriggerReadoutRecord_gtDigis__RECO_obj: struct (nullable = true)
#  |    |    |-- m_gtfeWord: struct (nullable = true)
#  |    |    |    |-- m_boardId: short (nullable = true)
#  |    |    |    |-- m_recordLength1: short (nullable = true)
#  |    |    |    |-- m_recordLength: short (nullable = true)
#  |    |    |    |-- m_bxNr: short (nullable = true)
#  |    |    |    |-- m_setupVersion: integer (nullable = true)
#  |    |    |    |-- m_activeBoards: short (nullable = true)
#  |    |    |    |-- m_altNrBxBoard: short (nullable = true)
#  |    |    |    |-- m_totalTriggerNr: integer (nullable = true)
#  |    |    |-- m_gtFdlWord: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- m_boardId: short (nullable = true)
#  |    |    |    |    |-- m_bxInEvent: integer (nullable = true)
#  |    |    |    |    |-- m_bxNr: short (nullable = true)
#  |    |    |    |    |-- m_eventNr: integer (nullable = true)
#  |    |    |    |    |-- m_gtTechnicalTriggerWord: array (nullable = true)
#  |    |    |    |    |    |-- element: boolean (containsNull = true)
#  |    |    |    |    |-- m_gtDecisionWord: array (nullable = true)
#  |    |    |    |    |    |-- element: boolean (containsNull = true)
#  |    |    |    |    |-- m_gtDecisionWordExtended: array (nullable = true)
#  |    |    |    |    |    |-- element: boolean (containsNull = true)
#  |    |    |    |    |-- m_physicsDeclared: short (nullable = true)
#  |    |    |    |    |-- m_gtPrescaleFactorIndexTech: short (nullable = true)
#  |    |    |    |    |-- m_gtPrescaleFactorIndexAlgo: short (nullable = true)
#  |    |    |    |    |-- m_noAlgo: short (nullable = true)
#  |    |    |    |    |-- m_finalOR: short (nullable = true)
#  |    |    |    |    |-- m_orbitNr: integer (nullable = true)
#  |    |    |    |    |-- m_lumiSegmentNr: short (nullable = true)
#  |    |    |    |    |-- m_localBxNr: short (nullable = true)
#  |    |    |-- m_gtPsbWord: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- m_boardId: short (nullable = true)
#  |    |    |    |    |-- m_bxInEvent: integer (nullable = true)
#  |    |    |    |    |-- m_bxNr: short (nullable = true)
#  |    |    |    |    |-- m_eventNr: integer (nullable = true)
#  |    |    |    |    |-- m_aData: array (nullable = true)
#  |    |    |    |    |    |-- element: short (containsNull = true)
#  |    |    |    |    |-- m_bData: array (nullable = true)
#  |    |    |    |    |    |-- element: short (containsNull = true)
#  |    |    |    |    |-- m_localBxNr: short (nullable = true)
#  |    |    |-- m_muCollRefProd: struct (nullable = true)
#  |    |    |    |-- product_: struct (nullable = true)
#  |    |    |    |    |-- processIndex_: short (nullable = true)
#  |    |    |    |    |-- productIndex_: short (nullable = true)
#  |-- double_fixedGridRhoAll__RECO_: struct (nullable = true)
#  |    |-- present: boolean (nullable = true)
#  |    |-- obj: double (nullable = true)
#  |-- double_fixedGridRhoFastjetAll__RECO_: struct (nullable = true)
#  |    |-- present: boolean (nullable = true)
#  |    |-- obj: double (nullable = true)
#  |-- double_ak5CaloJets_rho_RECO_: struct (nullable = true)
#  |    |-- present: boolean (nullable = true)
#  |    |-- obj: double (nullable = true)
#  |-- double_ak5PFJets_rho_RECO_: struct (nullable = true)
#  |    |-- present: boolean (nullable = true)
#  |    |-- obj: double (nullable = true)
#  |-- double_ak5TrackJets_rho_RECO_: struct (nullable = true)
#  |    |-- present: boolean (nullable = true)
#  |    |-- obj: double (nullable = true)
#  |-- double_ak7BasicJets_rho_RECO_: struct (nullable = true)
#  |    |-- present: boolean (nullable = true)
#  |    |-- obj: double (nullable = true)
#  |-- double_ak7CaloJets_rho_RECO_: struct (nullable = true)
#  |    |-- present: boolean (nullable = true)
#  |    |-- obj: double (nullable = true)
#  |-- double_ak7PFJets_rho_RECO_: struct (nullable = true)
#  |    |-- present: boolean (nullable = true)
#  |    |-- obj: double (nullable = true)
#  |-- double_kt4CaloJets_rho_RECO_: struct (nullable = true)
#  |    |-- present: boolean (nullable = true)
#  |    |-- obj: double (nullable = true)
#  |-- double_kt4PFJets_rho_RECO_: struct (nullable = true)
#  |    |-- present: boolean (nullable = true)
#  |    |-- obj: double (nullable = true)
#  |-- double_kt6CaloJets_rho_RECO_: struct (nullable = true)
#  |    |-- present: boolean (nullable = true)
#  |    |-- obj: double (nullable = true)
#  |-- double_kt6CaloJetsCentral_rho_RECO_: struct (nullable = true)
#  |    |-- present: boolean (nullable = true)
#  |    |-- obj: double (nullable = true)
#  |-- double_kt6PFJets_rho_RECO_: struct (nullable = true)
#  |    |-- present: boolean (nullable = true)
#  |    |-- obj: double (nullable = true)
#  |-- double_kt6PFJetsCentralChargedPileUp_rho_RECO_: struct (nullable = true)
#  |    |-- present: boolean (nullable = true)
#  |    |-- obj: double (nullable = true)
#  |-- double_kt6PFJetsCentralNeutral_rho_RECO_: struct (nullable = true)
#  |    |-- present: boolean (nullable = true)
#  |    |-- obj: double (nullable = true)
#  |-- double_kt6PFJetsCentralNeutralTight_rho_RECO_: struct (nullable = true)
#  |    |-- present: boolean (nullable = true)
#  |    |-- obj: double (nullable = true)
#  |-- double_ak5CaloJets_sigma_RECO_: struct (nullable = true)
#  |    |-- present: boolean (nullable = true)
#  |    |-- obj: double (nullable = true)
#  |-- double_ak5PFJets_sigma_RECO_: struct (nullable = true)
#  |    |-- present: boolean (nullable = true)
#  |    |-- obj: double (nullable = true)
#  |-- double_ak5TrackJets_sigma_RECO_: struct (nullable = true)
#  |    |-- present: boolean (nullable = true)
#  |    |-- obj: double (nullable = true)
#  |-- double_ak7BasicJets_sigma_RECO_: struct (nullable = true)
#  |    |-- present: boolean (nullable = true)
#  |    |-- obj: double (nullable = true)
#  |-- double_ak7CaloJets_sigma_RECO_: struct (nullable = true)
#  |    |-- present: boolean (nullable = true)
#  |    |-- obj: double (nullable = true)
#  |-- double_ak7PFJets_sigma_RECO_: struct (nullable = true)
#  |    |-- present: boolean (nullable = true)
#  |    |-- obj: double (nullable = true)
#  |-- double_kt4CaloJets_sigma_RECO_: struct (nullable = true)
#  |    |-- present: boolean (nullable = true)
#  |    |-- obj: double (nullable = true)
# ...
#  |    |    |    |-- recHits_: struct (nullable = true)
#  |    |    |    |    |-- refVector_: struct (nullable = true)
#  |    |    |    |    |    |-- recoTrackExtras_tevMuons_picky_RECO_obj_recHits__refVector__product_: struct (nullable = true)
#  |    |    |    |    |    |    |-- processIndex_: short (nullable = true)
#  |    |    |    |    |    |    |-- productIndex_: short (nullable = true)
#  |    |    |    |    |    |-- recoTrackExtras_tevMuons_picky_RECO_obj_recHits__refVector__keys_: array (nullable = true)
#  |    |    |    |    |    |    |-- element: integer (containsNull = true)
#  |    |    |    |-- outerPosition_: struct (nullable = true)
#  |    |    |    |    |-- fCoordinates: struct (nullable = true)
#  |    |    |    |    |    |-- fX: float (nullable = true)
#  |    |    |    |    |    |-- fY: float (nullable = true)
#  |    |    |    |    |    |-- fZ: float (nullable = true)
#  |    |    |    |-- outerMomentum_: struct (nullable = true)
#  |    |    |    |    |-- fCoordinates: struct (nullable = true)
#  |    |    |    |    |    |-- fX: float (nullable = true)
#  |    |    |    |    |    |-- fY: float (nullable = true)
#  |    |    |    |    |    |-- fZ: float (nullable = true)
#  |    |    |    |-- outerOk_: boolean (nullable = true)
#  |    |    |    |-- outerCovariance_: array (nullable = true)
#  |    |    |    |    |-- element: float (containsNull = true)
#  |    |    |    |-- outerDetId_: integer (nullable = true)
#  |    |    |    |-- innerPosition_: struct (nullable = true)
#  |    |    |    |    |-- fCoordinates: struct (nullable = true)
#  |    |    |    |    |    |-- fX: float (nullable = true)
#  |    |    |    |    |    |-- fY: float (nullable = true)
#  |    |    |    |    |    |-- fZ: float (nullable = true)
#  |    |    |    |-- innerMomentum_: struct (nullable = true)
#  |    |    |    |    |-- fCoordinates: struct (nullable = true)
#  |    |    |    |    |    |-- fX: float (nullable = true)
#  |    |    |    |    |    |-- fY: float (nullable = true)
#  |    |    |    |    |    |-- fZ: float (nullable = true)
#  |    |    |    |-- innerOk_: boolean (nullable = true)
#  |    |    |    |-- innerCovariance_: array (nullable = true)
#  |    |    |    |    |-- element: float (containsNull = true)
#  |    |    |    |-- innerDetId_: integer (nullable = true)
#  |    |    |    |-- seedDir_: integer (nullable = true)
#  |    |    |    |-- trackResiduals_: struct (nullable = true)
#  |    |    |    |    |-- residuals_: array (nullable = true)
#  |    |    |    |    |    |-- element: byte (containsNull = true)
#  |    |    |    |    |-- residualType: byte (nullable = true)
#  |-- recoTrackExtrapolations_trackExtrapolator__RECO_: struct (nullable = true)
#  |    |-- present: boolean (nullable = true)
#  |    |-- recoTrackExtrapolations_trackExtrapolator__RECO_obj: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- track_: struct (nullable = true)
#  |    |    |    |    |-- recoTrackExtrapolations_trackExtrapolator__RECO_obj_track__product_: struct (nullable = true)
#  |    |    |    |    |    |-- processIndex_: short (nullable = true)
#  |    |    |    |    |    |-- productIndex_: short (nullable = true)
#  |    |    |    |    |    |-- elementIndex_: integer (nullable = true)
#  |    |    |    |-- recoTrackExtrapolations_trackExtrapolator__RECO_obj_pos_: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- fCoordinates: struct (nullable = true)
#  |    |    |    |    |    |    |-- fX: double (nullable = true)
#  |    |    |    |    |    |    |-- fY: double (nullable = true)
#  |    |    |    |    |    |    |-- fZ: double (nullable = true)
#  |    |    |    |-- recoTrackExtrapolations_trackExtrapolator__RECO_obj_mom_: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- fCoordinates: struct (nullable = true)
#  |    |    |    |    |    |    |-- fX: double (nullable = true)
#  |    |    |    |    |    |    |-- fY: double (nullable = true)
#  |    |    |    |    |    |    |-- fZ: double (nullable = true)
#  |-- recoTrackJets_ak5TrackJets__RECO_: struct (nullable = true)
#  |    |-- present: boolean (nullable = true)
#  |    |-- recoTrackJets_ak5TrackJets__RECO_obj: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- qx3_: integer (nullable = true)
#  |    |    |    |-- pt_: float (nullable = true)
#  |    |    |    |-- eta_: float (nullable = true)
#  |    |    |    |-- phi_: float (nullable = true)
#  |    |    |    |-- mass_: float (nullable = true)
#  |    |    |    |-- vertex_: struct (nullable = true)
#  |    |    |    |    |-- fCoordinates: struct (nullable = true)
#  |    |    |    |    |    |-- fX: float (nullable = true)
#  |    |    |    |    |    |-- fY: float (nullable = true)
#  |    |    |    |    |    |-- fZ: float (nullable = true)
#  |    |    |    |-- pdgId_: integer (nullable = true)
#  |    |    |    |-- status_: integer (nullable = true)
#  |    |    |    |-- recoTrackJets_ak5TrackJets__RECO_obj_dau: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- core_: struct (nullable = true)
#  |    |    |    |    |    |    |-- processIndex_: short (nullable = true)
#  |    |    |    |    |    |    |-- productIndex_: short (nullable = true)
#  |    |    |    |    |    |-- key_: long (nullable = true)
#  |    |    |    |-- mJetArea: float (nullable = true)
#  |    |    |    |-- mPileupEnergy: float (nullable = true)
#  |    |    |    |-- mPassNumber: integer (nullable = true)
#  |    |    |    |-- vtx_: struct (nullable = true)
#  |    |    |    |    |-- recoTrackJets_ak5TrackJets__RECO_obj_vtx__product_: struct (nullable = true)
#  |    |    |    |    |    |-- processIndex_: short (nullable = true)
#  |    |    |    |    |    |-- productIndex_: short (nullable = true)
#  |    |    |    |    |    |-- elementIndex_: integer (nullable = true)
#  |-- recoVertexs_offlinePrimaryVertices__RECO_: struct (nullable = true)
#  |    |-- present: boolean (nullable = true)
#  |    |-- recoVertexs_offlinePrimaryVertices__RECO_obj: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- chi2_: float (nullable = true)
#  |    |    |    |-- ndof_: float (nullable = true)
#  |    |    |    |-- position_: struct (nullable = true)
#  |    |    |    |    |-- fCoordinates: struct (nullable = true)
#  |    |    |    |    |    |-- fX: double (nullable = true)
#  |    |    |    |    |    |-- fY: double (nullable = true)
#  |    |    |    |    |    |-- fZ: double (nullable = true)
#  |    |    |    |-- covariance_: array (nullable = true)
#  |    |    |    |    |-- element: float (containsNull = true)
#  |    |    |    |-- recoVertexs_offlinePrimaryVertices__RECO_obj_refittedTracks_: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- reco__TrackBase: struct (nullable = true)
#  |    |    |    |    |    |    |-- hitPattern_: struct (nullable = true)
#  |    |    |    |    |    |    |    |-- hitPattern_: array (nullable = true)
#  |    |    |    |    |    |    |    |    |-- element: integer (containsNull = true)
#  |    |    |    |    |    |    |-- trackerExpectedHitsInner_: struct (nullable = true)
#  |    |    |    |    |    |    |    |-- hitPattern_: array (nullable = true)
#  |    |    |    |    |    |    |    |    |-- element: integer (containsNull = true)
#  |    |    |    |    |    |    |-- trackerExpectedHitsOuter_: struct (nullable = true)
#  |    |    |    |    |    |    |    |-- hitPattern_: array (nullable = true)
#  |    |    |    |    |    |    |    |    |-- element: integer (containsNull = true)
#  |    |    |    |    |    |    |-- covariance_: array (nullable = true)
#  |    |    |    |    |    |    |    |-- element: float (containsNull = true)
#  |    |    |    |    |    |    |-- chi2_: float (nullable = true)
#  |    |    |    |    |    |    |-- vertex_: struct (nullable = true)
#  |    |    |    |    |    |    |    |-- fCoordinates: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |-- fX: float (nullable = true)
#  |    |    |    |    |    |    |    |    |-- fY: float (nullable = true)
#  |    |    |    |    |    |    |    |    |-- fZ: float (nullable = true)
#  |    |    |    |    |    |    |-- momentum_: struct (nullable = true)
#  |    |    |    |    |    |    |    |-- fCoordinates: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |-- fX: float (nullable = true)
#  |    |    |    |    |    |    |    |    |-- fY: float (nullable = true)
#  |    |    |    |    |    |    |    |    |-- fZ: float (nullable = true)
#  |    |    |    |    |    |    |-- ndof_: float (nullable = true)
#  |    |    |    |    |    |    |-- charge_: byte (nullable = true)
#  |    |    |    |    |    |    |-- algorithm_: byte (nullable = true)
#  |    |    |    |    |    |    |-- quality_: byte (nullable = true)
#  |    |    |    |    |    |    |-- nLoops_: byte (nullable = true)
#  |    |    |    |    |    |-- extra_: struct (nullable = true)
#  |    |    |    |    |    |    |-- product_: struct (nullable = true)
#  |    |    |    |    |    |    |    |-- processIndex_: short (nullable = true)
#  |    |    |    |    |    |    |    |-- productIndex_: short (nullable = true)
#  |    |    |    |    |    |    |    |-- elementIndex_: integer (nullable = true)
#  |    |    |    |-- recoVertexs_offlinePrimaryVertices__RECO_obj_weights_: array (nullable = true)
#  |    |    |    |    |-- element: byte (containsNull = true)
#  |    |    |    |-- validity_: boolean (nullable = true)
#  |-- recoVertexs_offlinePrimaryVerticesWithBS__RECO_: struct (nullable = true)
#  |    |-- present: boolean (nullable = true)
#  |    |-- recoVertexs_offlinePrimaryVerticesWithBS__RECO_obj: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- chi2_: float (nullable = true)
#  |    |    |    |-- ndof_: float (nullable = true)
#  |    |    |    |-- position_: struct (nullable = true)
#  |    |    |    |    |-- fCoordinates: struct (nullable = true)
#  |    |    |    |    |    |-- fX: double (nullable = true)
#  |    |    |    |    |    |-- fY: double (nullable = true)
#  |    |    |    |    |    |-- fZ: double (nullable = true)
#  |    |    |    |-- covariance_: array (nullable = true)
#  |    |    |    |    |-- element: float (containsNull = true)
#  |    |    |    |-- recoVertexs_offlinePrimaryVerticesWithBS__RECO_obj_refittedTracks_: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- reco__TrackBase: struct (nullable = true)
#  |    |    |    |    |    |    |-- hitPattern_: struct (nullable = true)
#  |    |    |    |    |    |    |    |-- hitPattern_: array (nullable = true)
#  |    |    |    |    |    |    |    |    |-- element: integer (containsNull = true)
#  |    |    |    |    |    |    |-- trackerExpectedHitsInner_: struct (nullable = true)
#  |    |    |    |    |    |    |    |-- hitPattern_: array (nullable = true)
#  |    |    |    |    |    |    |    |    |-- element: integer (containsNull = true)
#  |    |    |    |    |    |    |-- trackerExpectedHitsOuter_: struct (nullable = true)
#  |    |    |    |    |    |    |    |-- hitPattern_: array (nullable = true)
#  |    |    |    |    |    |    |    |    |-- element: integer (containsNull = true)
#  |    |    |    |    |    |    |-- covariance_: array (nullable = true)
#  |    |    |    |    |    |    |    |-- element: float (containsNull = true)
#  |    |    |    |    |    |    |-- chi2_: float (nullable = true)
#  |    |    |    |    |    |    |-- vertex_: struct (nullable = true)
#  |    |    |    |    |    |    |    |-- fCoordinates: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |-- fX: float (nullable = true)
#  |    |    |    |    |    |    |    |    |-- fY: float (nullable = true)
#  |    |    |    |    |    |    |    |    |-- fZ: float (nullable = true)
#  |    |    |    |    |    |    |-- momentum_: struct (nullable = true)
#  |    |    |    |    |    |    |    |-- fCoordinates: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |-- fX: float (nullable = true)
#  |    |    |    |    |    |    |    |    |-- fY: float (nullable = true)
#  |    |    |    |    |    |    |    |    |-- fZ: float (nullable = true)
#  |    |    |    |    |    |    |-- ndof_: float (nullable = true)
#  |    |    |    |    |    |    |-- charge_: byte (nullable = true)
#  |    |    |    |    |    |    |-- algorithm_: byte (nullable = true)
#  |    |    |    |    |    |    |-- quality_: byte (nullable = true)
#  |    |    |    |    |    |    |-- nLoops_: byte (nullable = true)
#  |    |    |    |    |    |-- extra_: struct (nullable = true)
#  |    |    |    |    |    |    |-- product_: struct (nullable = true)
#  |    |    |    |    |    |    |    |-- processIndex_: short (nullable = true)
#  |    |    |    |    |    |    |    |-- productIndex_: short (nullable = true)
#  |    |    |    |    |    |    |    |-- elementIndex_: integer (nullable = true)
#  |    |    |    |-- recoVertexs_offlinePrimaryVerticesWithBS__RECO_obj_weights_: array (nullable = true)
#  |    |    |    |    |-- element: byte (containsNull = true)
#  |    |    |    |-- validity_: boolean (nullable = true)
#  |-- recoVertexCompositeCandidates_generalV0Candidates_Kshort_RECO_: struct (nullable = true)
#  |    |-- present: boolean (nullable = true)
#  |    |-- recoVertexCompositeCandidates_generalV0Candidates_Kshort_RECO_obj: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- qx3_: integer (nullable = true)
#  |    |    |    |-- pt_: float (nullable = true)
#  |    |    |    |-- eta_: float (nullable = true)
#  |    |    |    |-- phi_: float (nullable = true)
#  |    |    |    |-- mass_: float (nullable = true)
#  |    |    |    |-- vertex_: struct (nullable = true)
#  |    |    |    |    |-- fCoordinates: struct (nullable = true)
#  |    |    |    |    |    |-- fX: float (nullable = true)
#  |    |    |    |    |    |-- fY: float (nullable = true)
#  |    |    |    |    |    |-- fZ: float (nullable = true)
#  |    |    |    |-- pdgId_: integer (nullable = true)
#  |    |    |    |-- status_: integer (nullable = true)
#  |    |    |    |-- name_: string (nullable = true)
#  |    |    |    |-- recoVertexCompositeCandidates_generalV0Candidates_Kshort_RECO_obj_roles_: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |-- chi2_: double (nullable = true)
#  |    |    |    |-- ndof_: double (nullable = true)
#  |    |    |    |-- covariance_: array (nullable = true)
#  |    |    |    |    |-- element: double (containsNull = true)
#  |-- recoVertexCompositeCandidates_generalV0Candidates_Lambda_RECO_: struct (nullable = true)
#  |    |-- present: boolean (nullable = true)
#  |    |-- recoVertexCompositeCandidates_generalV0Candidates_Lambda_RECO_obj: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- qx3_: integer (nullable = true)
#  |    |    |    |-- pt_: float (nullable = true)
#  |    |    |    |-- eta_: float (nullable = true)
#  |    |    |    |-- phi_: float (nullable = true)
#  |    |    |    |-- mass_: float (nullable = true)
#  |    |    |    |-- vertex_: struct (nullable = true)
#  |    |    |    |    |-- fCoordinates: struct (nullable = true)
#  |    |    |    |    |    |-- fX: float (nullable = true)
#  |    |    |    |    |    |-- fY: float (nullable = true)
#  |    |    |    |    |    |-- fZ: float (nullable = true)
#  |    |    |    |-- pdgId_: integer (nullable = true)
#  |    |    |    |-- status_: integer (nullable = true)
#  |    |    |    |-- name_: string (nullable = true)
#  |    |    |    |-- recoVertexCompositeCandidates_generalV0Candidates_Lambda_RECO_obj_roles_: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |-- chi2_: double (nullable = true)
#  |    |    |    |-- ndof_: double (nullable = true)
#  |    |    |    |-- covariance_: array (nullable = true)
#  |    |    |    |    |-- element: double (containsNull = true)

# %%
dsMuons = ds.select("recoMuons_muons__RECO_.recoMuons_muons__RECO_obj").toDF("muons")

# %%
dsMuons.printSchema()
# Out:
# root
#  |-- muons: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- qx3_: integer (nullable = true)
#  |    |    |-- pt_: float (nullable = true)
#  |    |    |-- eta_: float (nullable = true)
#  |    |    |-- phi_: float (nullable = true)
#  |    |    |-- mass_: float (nullable = true)
#  |    |    |-- vertex_: struct (nullable = true)
#  |    |    |    |-- fCoordinates: struct (nullable = true)
#  |    |    |    |    |-- fX: float (nullable = true)
#  |    |    |    |    |-- fY: float (nullable = true)
#  |    |    |    |    |-- fZ: float (nullable = true)
#  |    |    |-- pdgId_: integer (nullable = true)
#  |    |    |-- status_: integer (nullable = true)
#  |    |    |-- innerTrack_: struct (nullable = true)
#  |    |    |    |-- recoMuons_muons__RECO_obj_innerTrack__product_: struct (nullable = true)
#  |    |    |    |    |-- processIndex_: short (nullable = true)
#  |    |    |    |    |-- productIndex_: short (nullable = true)
#  |    |    |    |    |-- elementIndex_: integer (nullable = true)
#  |    |    |-- outerTrack_: struct (nullable = true)
#  |    |    |    |-- recoMuons_muons__RECO_obj_outerTrack__product_: struct (nullable = true)
#  |    |    |    |    |-- processIndex_: short (nullable = true)
#  |    |    |    |    |-- productIndex_: short (nullable = true)
#  |    |    |    |    |-- elementIndex_: integer (nullable = true)
#  |    |    |-- globalTrack_: struct (nullable = true)
#  |    |    |    |-- recoMuons_muons__RECO_obj_globalTrack__product_: struct (nullable = true)
#  |    |    |    |    |-- processIndex_: short (nullable = true)
#  |    |    |    |    |-- productIndex_: short (nullable = true)
#  |    |    |    |    |-- elementIndex_: integer (nullable = true)
#  |    |    |-- recoMuons_muons__RECO_obj_refittedTrackMap_: map (nullable = true)
#  |    |    |    |-- key: integer
#  |    |    |    |-- value: struct (valueContainsNull = true)
#  |    |    |    |    |-- product_: struct (nullable = true)
#  |    |    |    |    |    |-- processIndex_: short (nullable = true)
#  |    |    |    |    |    |-- productIndex_: short (nullable = true)
#  |    |    |    |    |    |-- elementIndex_: integer (nullable = true)
#  |    |    |-- bestTrackType_: integer (nullable = true)
#  |    |    |-- calEnergy_: struct (nullable = true)
#  |    |    |    |-- tower: float (nullable = true)
#  |    |    |    |-- towerS9: float (nullable = true)
#  |    |    |    |-- em: float (nullable = true)
#  |    |    |    |-- emS9: float (nullable = true)
#  |    |    |    |-- emS25: float (nullable = true)
#  |    |    |    |-- emMax: float (nullable = true)
#  |    |    |    |-- had: float (nullable = true)
#  |    |    |    |-- hadS9: float (nullable = true)
#  |    |    |    |-- hadMax: float (nullable = true)
#  |    |    |    |-- ho: float (nullable = true)
#  |    |    |    |-- hoS9: float (nullable = true)
#  |    |    |    |-- ecal_time: float (nullable = true)
#  |    |    |    |-- ecal_timeError: float (nullable = true)
#  |    |    |    |-- hcal_time: float (nullable = true)
#  |    |    |    |-- hcal_timeError: float (nullable = true)
#  |    |    |    |-- ecal_position: struct (nullable = true)
#  |    |    |    |    |-- fCoordinates: struct (nullable = true)
#  |    |    |    |    |    |-- fX: float (nullable = true)
#  |    |    |    |    |    |-- fY: float (nullable = true)
#  |    |    |    |    |    |-- fZ: float (nullable = true)
#  |    |    |    |-- hcal_position: struct (nullable = true)
#  |    |    |    |    |-- fCoordinates: struct (nullable = true)
#  |    |    |    |    |    |-- fX: float (nullable = true)
#  |    |    |    |    |    |-- fY: float (nullable = true)
#  |    |    |    |    |    |-- fZ: float (nullable = true)
#  |    |    |    |-- ecal_id: struct (nullable = true)
#  |    |    |    |    |-- id_: integer (nullable = true)
#  |    |    |    |-- hcal_id: struct (nullable = true)
#  |    |    |    |    |-- id_: integer (nullable = true)
#  |    |    |-- combinedQuality_: struct (nullable = true)
#  |    |    |    |-- updatedSta: boolean (nullable = true)
#  |    |    |    |-- trkKink: float (nullable = true)
#  |    |    |    |-- glbKink: float (nullable = true)
#  |    |    |    |-- trkRelChi2: float (nullable = true)
#  |    |    |    |-- staRelChi2: float (nullable = true)
#  |    |    |    |-- chi2LocalPosition: float (nullable = true)
#  |    |    |    |-- chi2LocalMomentum: float (nullable = true)
#  |    |    |    |-- localDistance: float (nullable = true)
#  |    |    |    |-- globalDeltaEtaPhi: float (nullable = true)
#  |    |    |    |-- tightMatch: boolean (nullable = true)
#  |    |    |    |-- glbTrackProbability: float (nullable = true)
#  |    |    |    |-- tkKink_position: struct (nullable = true)
#  |    |    |    |    |-- fCoordinates: struct (nullable = true)
#  |    |    |    |    |    |-- fX: double (nullable = true)
#  |    |    |    |    |    |-- fY: double (nullable = true)
#  |    |    |    |    |    |-- fZ: double (nullable = true)
#  |    |    |    |-- glbKink_position: struct (nullable = true)
#  |    |    |    |    |-- fCoordinates: struct (nullable = true)
#  |    |    |    |    |    |-- fX: double (nullable = true)
#  |    |    |    |    |    |-- fY: double (nullable = true)
#  |    |    |    |    |    |-- fZ: double (nullable = true)
#  |    |    |-- time_: struct (nullable = true)
#  |    |    |    |-- nDof: integer (nullable = true)
#  |    |    |    |-- timeAtIpInOut: float (nullable = true)
#  |    |    |    |-- timeAtIpInOutErr: float (nullable = true)
#  |    |    |    |-- timeAtIpOutIn: float (nullable = true)
#  |    |    |    |-- timeAtIpOutInErr: float (nullable = true)
#  |    |    |-- energyValid_: boolean (nullable = true)
#  |    |    |-- matchesValid_: boolean (nullable = true)
#  |    |    |-- isolationValid_: boolean (nullable = true)
#  |    |    |-- pfIsolationValid_: boolean (nullable = true)
#  |    |    |-- qualityValid_: boolean (nullable = true)
#  |    |    |-- caloCompatibility_: float (nullable = true)
#  |    |    |-- isolationR03_: struct (nullable = true)
#  |    |    |    |-- sumPt: float (nullable = true)
#  |    |    |    |-- emEt: float (nullable = true)
#  |    |    |    |-- hadEt: float (nullable = true)
#  |    |    |    |-- hoEt: float (nullable = true)
#  |    |    |    |-- nTracks: integer (nullable = true)
#  |    |    |    |-- nJets: integer (nullable = true)
#  |    |    |    |-- trackerVetoPt: float (nullable = true)
#  |    |    |    |-- emVetoEt: float (nullable = true)
#  |    |    |    |-- hadVetoEt: float (nullable = true)
#  |    |    |    |-- hoVetoEt: float (nullable = true)
#  |    |    |-- isolationR05_: struct (nullable = true)
#  |    |    |    |-- sumPt: float (nullable = true)
#  |    |    |    |-- emEt: float (nullable = true)
#  |    |    |    |-- hadEt: float (nullable = true)
#  |    |    |    |-- hoEt: float (nullable = true)
#  |    |    |    |-- nTracks: integer (nullable = true)
#  |    |    |    |-- nJets: integer (nullable = true)
#  |    |    |    |-- trackerVetoPt: float (nullable = true)
#  |    |    |    |-- emVetoEt: float (nullable = true)
#  |    |    |    |-- hadVetoEt: float (nullable = true)
#  |    |    |    |-- hoVetoEt: float (nullable = true)
#  |    |    |-- pfIsolationR03_: struct (nullable = true)
#  |    |    |    |-- sumChargedHadronPt: float (nullable = true)
#  |    |    |    |-- sumChargedParticlePt: float (nullable = true)
#  |    |    |    |-- sumNeutralHadronEt: float (nullable = true)
#  |    |    |    |-- sumPhotonEt: float (nullable = true)
#  |    |    |    |-- sumNeutralHadronEtHighThreshold: float (nullable = true)
#  |    |    |    |-- sumPhotonEtHighThreshold: float (nullable = true)
#  |    |    |    |-- sumPUPt: float (nullable = true)
#  |    |    |-- pfIsolationR04_: struct (nullable = true)
#  |    |    |    |-- sumChargedHadronPt: float (nullable = true)
#  |    |    |    |-- sumChargedParticlePt: float (nullable = true)
#  |    |    |    |-- sumNeutralHadronEt: float (nullable = true)
#  |    |    |    |-- sumPhotonEt: float (nullable = true)
#  |    |    |    |-- sumNeutralHadronEtHighThreshold: float (nullable = true)
#  |    |    |    |-- sumPhotonEtHighThreshold: float (nullable = true)
#  |    |    |    |-- sumPUPt: float (nullable = true)
#  |    |    |-- type_: integer (nullable = true)
#  |    |    |-- pfP4_: struct (nullable = true)
#  |    |    |    |-- fCoordinates: struct (nullable = true)
#  |    |    |    |    |-- fX: double (nullable = true)
#  |    |    |    |    |-- fY: double (nullable = true)
#  |    |    |    |    |-- fZ: double (nullable = true)
#  |    |    |    |    |-- fT: double (nullable = true)

# %%
dsMuons.show()
# Out:
# +--------------------+
# |               muons|
# +--------------------+
# |[[-3,20.111635,-1...|
# |[[-3,49.427155,-2...|
# |[[-3,2.2016237,-1...|
# |[[3,33.72951,-2.3...|
# |[[-3,3.9327354,-1...|
# |[[3,21.213083,-2....|
# |[[-3,6.4963756,-2...|
# |[[-3,40.716217,1....|
# |[[3,1.9911032,2.1...|
# |[[3,70.31914,1.69...|
# |[[-3,73.06647,-2....|
# |[[3,9.637147,-1.0...|
# |[[3,42.748066,-2....|
# |[[-3,27.396252,1....|
# |[[3,3.5388916,-1....|
# |[[-3,36.111237,2....|
# |[[-3,4.989803,-2....|
# |[[-3,36.44466,-0....|
# |[[3,34.97526,-1.2...|
# |[[3,68.98857,-1.7...|
# +--------------------+
# only showing top 20 rows

# %%
# helper function to calculate isolation from the struct
def iso(isoStruct): 
    neutral = max(0.0, isoStruct.sumNeutralHadronEt + isoStruct.sumPhotonEt - 0.5 * isoStruct.sumPUPt)
    return isoStruct.sumChargedHadronPt + neutral

# just do the looser muon selection here.  will do a second selection for leading muon later
def passMuonSel(muon):
    return ((muon.pt_ > 10.0) and 
        (fabs(muon.eta_) < 2.4) and
        (iso(muon.pfIsolationR04_)/muon.pt_ < 0.5) and
        ((muon.type_ & (1<<1)) != 0)) # global muon 

# method to apply the event level selection cuts,
#  including tighter cuts on the leading muon
def passEventSel(muons):
    return ((len(muons) > 1) and
            (muons[0].pt_ > 25.0) and
            (fabs(muons[0].eta_) < 2.1) and
            (iso(muons[0].pfIsolationR04_)/muons[0].pt_ < 0.12) and
            (muons[0].pdgId_ * muons[1].pdgId_ < 0))

# simplified formula, assuming E >> m
def invariantMass(mu1, mu2):
    return sqrt(2*mu1.pt_*mu2.pt_*(cosh(mu1.eta_-mu2.eta_)-cos(mu1.phi_-mu2.phi_)))
    
def handleEvent(event):
    # first select muons
    selMuons = [muon for muon in event.muons if passMuonSel(muon)]
    # sort in decreasing order of muon pT - makes a noticeable difference in how many events pass
    # if not sorting, can reproduce the scala results exactly
    #sortedMuons = sorted(selMuons, key=lambda muon: -muon.pt_)
    sortedMuons = selMuons
    # check if event passes selection (including requiring at least 2 muons)
    if passEventSel(sortedMuons):
        return [invariantMass(sortedMuons[0], sortedMuons[1])]
        ### from victor's example:
        # muon1, muon2 = sortedMuons[:2]
        # return [Row(mass=invariantMass(muon1, muon2), pt1=muon1.pt_, phi1=muon1.phi_, eta1=muon1.eta_, pt2=muon2.pt_, phi2=muon2.phi_, eta2=muon2.eta_)]
    else:
        return []

# %%
#dsDimuons = dsMuons.rdd.filter(lambda event: len(event.muons) > 1)
#print dsDimuons.count()

# %%
# do all the steps at once.. didn't immediately see how to do object selection in a separate step
dsMll = dsMuons.rdd.flatMap(handleEvent).map(lambda x: (x, )).toDF().persist()

# %%
dsMll.show()
# Out:
# +------------------+
# |                _1|
# +------------------+
# | 75.17152550288458|
# | 72.40964018091776|
# |   91.587498504177|
# | 83.44084509897125|
# | 93.57815817875573|
# | 90.00495283242167|
# | 82.86015951533207|
# | 81.95454594633969|
# | 83.10113910084489|
# | 66.45596691200133|
# | 79.47300208296096|
# | 91.44308967574325|
# | 68.42604644840561|
# | 51.22710389646728|
# | 51.72832692826305|
# | 308.0664543788408|
# | 51.83220175373299|
# | 90.88472726085514|
# |59.662699748378635|
# | 36.30271355896827|
# +------------------+
# only showing top 20 rows

# %%
dsMll.write.parquet("file:/tmp/olivito/test_results_mll_pyspark.parquet", mode="overwrite")
